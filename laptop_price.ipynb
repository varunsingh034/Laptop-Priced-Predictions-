# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression,SGDRegressor

# %%
df = pd.read_csv('laptopPrice.csv')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand'].unique()# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],dtype=object)

dt = {
    'ASUS' : 0,
    'Lenovo' : 1,
    'acer' : 2,
    'Avita' : 3,
    'HP' : 4,
    'DELL' : 5,
    'MSI' : 6,
    'APPLE' : 7
}

df['brand'] = df['brand'].map(dt)
df
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        0           Intel        Core i3            10th   4 GB     DDR4
# 1        1           Intel        Core i3            10th   4 GB     DDR4
# 2        1           Intel        Core i3            10th   4 GB     DDR4
# 3        0           Intel        Core i5            10th   8 GB     DDR4
# 4        0           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818      0             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819      0             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820      0             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821      0             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822      1             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df['processor_brand'].value_counts()

# processor_brand
# Intel    594
# AMD      189
# M1        19
# Name: count, dtype: int64

dt ={
    'Intel' : 0,
    'AMD' : 1,
    'M1' : 2
}

df['processor_brand'] = df['processor_brand'].map(dt)
df
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        0                0        Core i3            10th   4 GB     DDR4
# 1        1                0        Core i3            10th   4 GB     DDR4
# 2        1                0        Core i3            10th   4 GB     DDR4
# 3        0                0        Core i5            10th   8 GB     DDR4
# 4        0                0   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818      0                1        Ryzen 9   Not Available   4 GB     DDR4
# 819      0                1        Ryzen 9   Not Available   4 GB     DDR4
# 820      0                1        Ryzen 9   Not Available   4 GB     DDR4
# 821      0                1        Ryzen 9   Not Available   4 GB     DDR4
# 822      1                1        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['processor_name'].value_counts()

# processor_name
# Core i5         284
# Core i3         161
# Core i7         104
# Ryzen 5          82
# Ryzen 7          56
# Ryzen 9          26
# Ryzen 3          26
# Celeron Dual     23
# M1               19
# Pentium Quad     13
# Core i9           8
# Name: count, dtype: int64

dt = { 
    'Core i5' : 0,
    'Core i3' : 1,
    'Core i7' : 2,
    'Ryzen 5' : 3,
    'Ryzen 7' : 4,
    'Ryzen 9' : 5,
    'Ryzen 3' : 6,
    'Celeron Dual' : 7,
    'M1' : 8,
    'Pentium Quad' : 9,
    'Core i9' : 10
    }

df['processor_name'] = df['processor_name'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name processor_gnrtn ram_gb ram_type  \
# 0        0                0               1            10th   4 GB     DDR4
# 1        1                0               1            10th   4 GB     DDR4
# 2        1                0               1            10th   4 GB     DDR4
# 3        0                0               0            10th   8 GB     DDR4
# 4        0                0               7   Not Available   4 GB     DDR4
# ..     ...              ...             ...             ...    ...      ...
# 818      0                1               5   Not Available   4 GB     DDR4
# 819      0                1               5   Not Available   4 GB     DDR4
# 820      0                1               5   Not Available   4 GB     DDR4
# 821      0                1               5   Not Available   4 GB     DDR4
# 822      1                1               3            10th   8 GB     DDR4
#
# ...

# %%
df['processor_gnrtn'].value_counts()

# processor_gnrtn
# 11th             328
# Not Available    224
# 10th             198
# 8th               35
# 7th                7
# 9th                6
# 12th               3
# 4th                1
# Name: count, dtype: int64

dt = {
    '11th' : 0,
    'Not Available' : 1,
    '10th' : 2,
    '8th' : 3,
    '7th' : 4,
    '9th' : 5,
    '12th' : 6,
    '4th' : 7
}

df['processor_gnrtn'] = df['processor_gnrtn'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn ram_gb ram_type  \
# 0        0                0               1                2   4 GB     DDR4
# 1        1                0               1                2   4 GB     DDR4
# 2        1                0               1                2   4 GB     DDR4
# 3        0                0               0                2   8 GB     DDR4
# 4        0                0               7                1   4 GB     DDR4
# ..     ...              ...             ...              ...    ...      ...
# 818      0                1               5                1   4 GB     DDR4
# 819      0                1               5                1   4 GB     DDR4
# 820      0                1               5                1   4 GB     DDR4
# 821      0                1               5                1   4 GB     DDR4
# 822      1                1               3                2   8 GB     DDR4
#
# ...

# %%
df['ram_gb'].value_counts()

# ram_gb
# 8 GB     404
# 4 GB     223
# 16 GB    173
# 32 GB      2
# Name: count, dtype: int64

df[['ram_in_gb', 'ram']] = df['ram_gb'].str.split(n=1,expand=True)
df.drop(columns=['ram_gb','ram'],inplace=True)
df['ram_in_gb'] = df['ram_in_gb'].astype(int)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn ram_type  \
# 0        0                0               1                2     DDR4
# 1        1                0               1                2     DDR4
# 2        1                0               1                2     DDR4
# 3        0                0               0                2     DDR4
# 4        0                0               7                1     DDR4
# ..     ...              ...             ...              ...      ...
# 818      0                1               5                1     DDR4
# 819      0                1               5                1     DDR4
# 820      0                1               5                1     DDR4
# 821      0                1               5                1     DDR4
# 822      1                1               3                2     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df['ram_type'].value_counts()

# ram_type
# DDR4       690
# LPDDR4X     56
# LPDDR4      27
# LPDDR3      14
# DDR5         8
# DDR3         7
# Name: count, dtype: int64

dt = {
    'DDR4' : 0,
    'LPDDR4X' : 1,
    'LPDDR4' : 2,
    'LPDDR3' : 3,
    'DDR5' : 4,
    'DDR3' : 5
}

df['ram_type'] = df['ram_type'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  \
# 0        0                0               1                2         0
# 1        1                0               1                2         0
# 2        1                0               1                2         0
# 3        0                0               0                2         0
# 4        0                0               7                1         0
# ..     ...              ...             ...              ...       ...
# 818      0                1               5                1         0
# 819      0                1               5                1         0
# 820      0                1               5                1         0
# 821      0                1               5                1         0
# 822      1                1               3                2         0
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df['ssd'].value_counts()

# ssd
# 512 GB     389
# 256 GB     174
# 0 GB       123
# 1024 GB    110
# 128 GB       3
# 2048 GB      2
# 3072 GB      1
# Name: count, dtype: int64

df[['ssd_in_gb' , 'ssd_size']] = df['ssd'].str.split(' ',expand=True)
df.drop(columns=['ssd','ssd_size'],inplace= True)
df['ssd_in_gb'] = df['ssd_in_gb'].astype(int)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  \
# 0        0                0               1                2         0
# 1        1                0               1                2         0
# 2        1                0               1                2         0
# 3        0                0               0                2         0
# 4        0                0               7                1         0
# ..     ...              ...             ...              ...       ...
# 818      0                1               5                1         0
# 819      0                1               5                1         0
# 820      0                1               5                1         0
# 821      0                1               5                1         0
# 822      1                1               3                2         0
#
#          hdd       os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df['hdd'].value_counts()

# hdd
# 0 GB       602
# 1024 GB    159
# 512 GB      40
# 2048 GB      1
# Name: count, dtype: int64

df[['hdd_in_gb' , 'hdd_size']] = df['hdd'].str.split(' ',expand=True)
df.drop(columns=['hdd','hdd_size'],inplace= True)
df['hdd_in_gb'] = df['hdd_in_gb'].astype(int)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  \
# 0        0                0               1                2         0
# 1        1                0               1                2         0
# 2        1                0               1                2         0
# 3        0                0               0                2         0
# 4        0                0               7                1         0
# ..     ...              ...             ...              ...       ...
# 818      0                1               5                1         0
# 819      0                1               5                1         0
# 820      0                1               5                1         0
# 821      0                1               5                1         0
# 822      1                1               3                2         0
#
#           os  os_bit graphic_card_gb      weight     warranty Touchscreen  \
# ...

# %%
df['os'].value_counts()

# os
# Windows    763
# Mac         23
# DOS         16
# Name: count, dtype: int64

dt = {
    'Windows' : 0,
    'Mac' : 1,
    'DOS' : 2
}

df['os'] = df['os'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['os_bit'].value_counts()

# os_bit
# 64-bit    693
# 32-bit    109
# Name: count, dtype: int64

dt = {
    '64-bit' : 0,
    '32-bit' : 1
}

df['os_bit'] = df['os_bit'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['graphic_card_gb'].value_counts()

# graphic_card_gb
# 0 GB    557
# 4 GB    127
# 2 GB     67
# 6 GB     37
# 8 GB     14
# Name: count, dtype: int64

df[['gfx_gb','gfx']] = df['graphic_card_gb'].str.split(' ',expand=True)
df.drop(columns=['gfx','graphic_card_gb'],inplace=True)
df['gfx_gb'] = df['gfx_gb'].astype(int)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['weight'].value_counts()

# weight
# Casual        509
# ThinNlight    254
# Gaming         39
# Name: count, dtype: int64

dt = {
    'Casual' : 0,
    'ThinNlight' : 1,
    'Gaming' : 2
}

df['weight'] = df['weight'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['warranty'].value_counts()

# warranty
# 1 year         498
# No warranty    268
# 2 years         23
# 3 years         13
# Name: count, dtype: int64

dt = {
    '1 year' : 0,
    '2 years' : 1,
    '3 years' : 2,
    'No warranty' : 3
}

df['warranty'] = df['warranty'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['Touchscreen'].value_counts()

# Touchscreen
# No     706
# Yes     96
# Name: count, dtype: int64

dt = {
    'Yes' : 1,
    'No' : 0
}

df['Touchscreen'] = df['Touchscreen'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['msoffice'].value_counts()

# msoffice
# No     522
# Yes    280
# Name: count, dtype: int64

dt = {
    'Yes' : 1,
    'No' : 0
}

df['msoffice'] = df['msoffice'].map(dt)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
df['rating'].value_counts()

# rating
# 4 stars    437
# 3 stars    338
# 5 stars     16
# 2 stars      9
# 1 star       2
# Name: count, dtype: int64

df[['rating_star', 'r']] = df['rating'].str.split(' ',expand=True)
df.drop(columns=['r','rating'],inplace=True)
df['rating_star'] = df['rating_star'].astype(int)
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
#      os_bit  weight  warranty  Touchscreen  msoffice   Price  \
# ...

# %%
x = df.iloc[:,:].drop(columns=['Price'])
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 0        0                0               1                2         0   0
# 1        1                0               1                2         0   0
# 2        1                0               1                2         0   0
# 3        0                0               0                2         0   0
# 4        0                0               7                1         0   0
# ..     ...              ...             ...              ...       ...  ..
# 818      0                1               5                1         0   0
# 819      0                1               5                1         0   0
# 820      0                1               5                1         0   0
# 821      0                1               5                1         0   0
# 822      1                1               3                2         0   2
#
# ...

# %%
y = df['Price']
y
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 802, dtype: int64

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size=0.03,random_state=42)

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 31       2                0               1                0         0   0
# 271      1                0               0                2         0   0
# 574      1                0               2                2         0   0
# 212      2                0               0                3         0   0
# 80       1                0               1                0         0   0
# ..     ...              ...             ...              ...       ...  ..
# 73       1                0               1                2         0   0
# 108      5                0               1                0         0   0
# 275      1                0               0                2         0   0
# 445      0                0               0                0         0   0
# 104      0                0               1                0         0   0
#
# ...

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_type  os  \
# 196      2                0               0                1         4   0
# 299      0                0               0                0         1   0
# 171      5                0               1                2         0   0
# 537      4                0               2                2         0   0
# 551      6                0               2                0         0   0
# 809      0                1               5                1         1   0
# 610      7                2               8                2         0   1
# 328      2                0               0                3         5   0
# 222      1                0               0                0         0   0
# 415      1                0               0                2         0   0
# 68       0                0               1                0         0   0
# ...

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
rf = RandomForestRegressor()
rf.fit(x_train_scaled,y_train)
rf.score(x_test_scaled,y_test)
# Out:
# 0.6146949908420973

# %%
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
# Out:
# 0.6232903790303259

# %%
xgb = XGBRegressor()
xgb.fit(x_train_scaled,y_train)
xgb.score(x_test_scaled,y_test)
# Out:
# 0.7189652919769287

# %%
lr =  LinearRegression()
lr.fit(x_test_scaled,y_test)
lr.score(x_test_scaled,y_test)
# Out:
# 0.9770886403655384

# %%
sgd = SGDRegressor()
sgd.fit(x_train_scaled,y_train)
sgd.score(x_test_scaled,y_test)
# Out:
# 0.6246811477876925

# %%
import joblib 
joblib.dump(lr,'model.joblib')
# Out:
# ['model.joblib']
